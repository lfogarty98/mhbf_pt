# %% [markdown]
# <div>
#   <img style="float: left;"  width="140" src=" data:image/png;base64,...">
# </div>
#
# <h1 id="course-title-heading">
#     <div style="text-align: right">
#         Models of Higher Brain Functions
#         <br>Computer Course
#         <br>
#     </div>
# </h1>
#
# ---
# <div style="text-align: left; float: left">
#     Lecturer: Prof. Dr. Henning Sprekeler
# </div>
#
# <div style="text-align: right">
#     Assistant: Felix Lundt
#     <br>(lundt@tu-berlin.de)
# </div>

# %% [markdown]
# ## General exercise instructions
# These exercises should be completed entirely in this Jupyter Notebook (comprising source code, discussion and interpretation). Submission should be done through the Moodle interface and should consist only of this notebook (**a single `.ipynb` file**). This Jupyter Notebook was provided inside a `.zip` file, alongside additional files. Do not change the relative paths of these files when working on the assignment (meaning that e.g. `./helper.py` should always be in the same directory as this notebook).
#
# Submission deadline is the start of the next lectue (**10:15 am on Fridays**).
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Some of the exercises will be automatically graded. Make sure that you:
# 1. Fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE"
# 2. Remove all `raise NotImplementedError` lines once you inserted your solution
# 3. Don't use variable names starting with underscore (e.g. `_myvar`) in your code, which could interfere with the automatic grading system.
#
# Before you start, please fill in below your names and the name of your group as shown on Moodle. Example:
# ```
# NAMES = ["Martina Musterfrau", "John Smith"]
# GROUP = "A"
# ```
#
# If you have any questions about the exercises, please ask them **on the Moodle forum** of the course.

# %%
NAMES = ["Ghadi El Hasbani", "Liam Fogarty"]
GROUP = "G"

# %%
# These are a few tests to make sure that your installed Python software is not too old
import sys
assert sys.version_info.major >= 3, "Your Python version is too old, please update it."

import IPython
assert IPython.version_info[0] >= 3, "Your IPython version is too old, please update it."

# %% [markdown]
# ---

# %% [markdown]
# # Week 8: Reinforcement Learning II

# %%
# Necessary imports for this exercise, you can't modify these
import numpy as np
import matplotlib.pyplot as plt

# Import functions defined in the ./helpers.py file
from helpers import assert_var_defined, display_animation

# Import the GridWorld class
from gridworld import Gridworld

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1: Good vs. bad Döner (7 points)
#
# Consider a hungry reinforcement learning agent standing in a street with a bad and a good Döner shop, which are at different ends of the street. The goal of this exercise is to study the effects of the discount factor on the behavior of the agent.

# %% [markdown]
# ### 1.1 Implemente a linear Döner-world (3 points)
#
# Write a program that implements an agent in an environment of 50 linearly arranged states (corresponding to different positions along the street). In each state, the agent can choose among 2 actions: up or down, which take it to the respective neighboring states. In every trial, it starts in a random position. If the agent walks up in the top-most state, it receives a reward of 100 (bad Döner). If it walks down in the bottom-most state, it gets a reward of 1000 (good Döner). For every step that does not lead to a reward, the agent gets a negative reward of −10 (still no Döner). If either of the Döners is received, the trial ends and the agent starts a new trial at a new random position. Initialize the Q-values with small random numbers and let the agent learn according to the SARSA algorithm:
#
# $$
# \Delta Q(s_{t},a_{t}) = \eta (r_{t}+ \gamma Q(s_{t+1},a_{t+1}) - Q(s_{t},a_{t})) \, ,
# $$
#
# with $\eta$ = 0.1. The agent should follow an $\epsilon$-greedy policy with $\epsilon$ = 0.1. At the end of each trial, store the mean of all Q-values and the number of steps of the agent.
#
# *Hint: Terminal states in this setting require special attention. To ensure that the TD-error can go to zero in the last iteration, you can introduce two additional states at the borders of the environment whose Q-values are always 0.*

# %%
class LinearDonerWorld:
    
    def __init__(self, length: int = 50, eta: float = 0.1, gamma: float = 1.0, seed: int = 1):
        self.seed = seed
        np.random.seed(self.seed)
        
        self.length = length
        
        self.q_values = np.random.uniform(0, 1, (self.length + 2, 2))
        self.q_values[0] = np.array([0, 0])
        self.q_values[-1] = np.array([0, 0])
        
        self.rewards = np.full(self.length + 2, -10)
        self.rewards[0] = 1000
        self.rewards[-1] = 100
        
        self.eta = eta
        self.gamma = gamma
        
        self.positions_tracker = [np.random.randint(1, self.length + 1)]
        
    def get_optimal_action(self):
        up = self.q_values[self.positions_tracker[-1], 0] > self.q_values[self.positions_tracker[-1], 1]
        return up
        
    def pick_action_with_epsilon_greedy(self, epsilon: float):
        up = self.get_optimal_action()
        up = np.random.choice(np.array([up, not up])) if np.random.random() < epsilon else up
        return up
    
    def take_action(self, up):
        if up:
            self.positions_tracker.append(self.positions_tracker[-1] + 1)
        else:
            self.positions_tracker.append(self.positions_tracker[-1] - 1)
        
    def update_with_sarsa(self, up):
        col_idx = 0 if up else 1
        col_idx_previous = 0 if self.positions_tracker[-2] < self.positions_tracker[-1] else 1
        self.q_values[self.positions_tracker[-2], col_idx_previous] += self.eta*(self.rewards[self.positions_tracker[-1]] + self.gamma*self.q_values[self.positions_tracker[-1], col_idx] - self.q_values[self.positions_tracker[-2], col_idx_previous])
        
    def train_with_epsilon_greedy(self, n_trials: int, epsilon: float = 0.1):
        mean_q_values = np.zeros(n_trials)
        trial_durations = np.zeros(n_trials)
        for trial in range(n_trials):
            up = self.pick_action_with_epsilon_greedy(epsilon)
            while self.length + 1 > self.positions_tracker[-1] > 0:
                self.take_action(up)
                up = self.pick_action_with_epsilon_greedy(epsilon)
                self.update_with_sarsa(up)
            trial_durations[trial] = len(self.positions_tracker) - 1
            mean_q_values[trial] = np.mean(self.q_values[1:-1])
            self.positions_tracker = [np.random.randint(1, self.length + 1)]
            
            
        return mean_q_values , trial_durations

# %% [markdown]
# ### 1.2 Implement the agent
#
# #### 1.2 a) Simulate the first agent (0.5 points)
#
# Start with $\gamma$ = 1. Let the agent learn for 50,000 trials to make sure that the Q-values have converged. Then plot the following:
# 1. The duration of the trials as a function of trial number. This shows you if the agent is learning.
# 2. The mean of all Q-values as a function of trial number. This gives you an estimate of when the Q-values have converged.
#
# Generate the same plot again but this time zoom in into the first 500 trials.

# %%
# YOUR CODE HERE
gamma = 1.0
n_trials = 50000
linear_doner_world = LinearDonerWorld(gamma = gamma)
mean_q_values , trial_durations = linear_doner_world.train_with_epsilon_greedy(n_trials = n_trials)

# %%
fig, ax = plt.subplots(2, 2, figsize=(6,5), sharex = 'col', sharey = 'row')

ax[0, 0].plot(np.arange(1, n_trials + 1), trial_durations)
ax[0, 0].set_ylabel('# of Iterations')

ax[1, 0].plot(np.arange(1, n_trials + 1), mean_q_values)
ax[1, 0].set_xlabel('Trial #')
ax[1, 0].set_ylabel('Mean Q-value')

ax[0, 1].plot(np.arange(1, n_trials + 1)[:500], trial_durations[:500])

ax[1, 1].plot(np.arange(1, n_trials + 1)[:500], mean_q_values[:500])
ax[1, 1].set_xlabel('Trial #')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.2 b) Explain your results (0.5 points)
#
# You will observe that the agent’s behavior improves a lot faster than the Q-values converge - explain why!

# %% [markdown]
# The linear nature of the track and the placement of the rewards at the end lead to the Q-value information propagating throughout the track in relatively little time. Once the Q-values are updated from 0, the agent is less likely to oscillate between actions (mostly subject to the choice of $\epsilon$), since the Q-values monotonically increase towards the value of the closest reward, leading to shorter trial time.

# %% [markdown]
# #### 1.2 c) Plot the converged Q-values (1 point)
#
# 1. Plot two curves showing the final Q-values (after the 50.000 learning trials) over states - one curve for walking up and one for walking down.
# 2. In another figure, show the preferred action as a function of the state (up → 1, down → -1).

# %%
linear_doner_world.q_values
# Out:
# array([[   0.        ,    0.        ],
#        [ 975.27136317, 1000.        ],
#        [ 963.46977293,  989.75259701],
#        [ 952.85238536,  978.85482701],
#        [ 943.276899  ,  967.87216621],
#        [ 931.06801278,  955.95284491],
#        [ 920.45471212,  944.09051508],
#        [ 908.41408337,  929.24192797],
#        [ 898.9795665 ,  921.70685874],
#        [ 887.62647496,  912.27843571],
#        [ 878.07454347,  901.68913147],
#        [ 866.74661849,  890.88981988],
#        [ 855.95362728,  880.05681674],
#        [ 842.6108779 ,  869.29079329],
#        [ 833.37901211,  858.60347874],
#        [ 820.94432919,  846.51027806],
#        [ 808.85023528,  834.80533195],
#        [ 796.76156097,  820.69606284],
#        [ 788.30192336,  813.04738121],
#        [ 776.39116585,  802.6516064 ],
#        [ 766.54729047,  787.88615527],
#        [ 755.55533655,  779.41369559],
#        [ 745.1840165 ,  769.15933293],
#        [ 730.78461702,  758.82684706],
#        [ 721.7674451 ,  747.17731169],
#        [ 707.90750659,  734.77150063],
#        [ 697.81596724,  721.69921828],
#        [ 685.96432273,  710.56988964],
#        [ 674.12072159,  700.03722632],
#        [ 664.88036353,  689.45276154],
#        [ 654.23106275,  677.60291425],
#        [ 640.25071308,  663.35112277],
#        [ 631.96042619,  655.02361528],
#        [ 621.11399052,  645.29798298],
#        [ 611.01368566,  634.66484244],
#        [ 597.64637293,  624.39900377],
#        [ 587.14831526,  614.73225954],
#        [ 575.71310882,  604.31574369],
#        [ 563.50865368,  592.52009925],
#        [ 553.67508079,  580.56366794],
#        [ 541.83312853,  569.16239167],
#        [ 529.01355043,  557.06384316],
#        [ 517.51900529,  546.81779096],
#        [ 508.09023136,  534.49372549],
#        [ 499.84940717,  521.1472792 ],
#        [ 485.19994372,  508.04533655],
#        [ 476.61206401,  497.15856621],
#        [ 464.91561112,  485.7206014 ],
#        [ 450.83427765,  476.24483673],
#        [ 442.36690891,  466.14489129],
#        [ 100.        ,  455.0830196 ],
#        [   0.        ,    0.        ]])

# %%
plt.plot(np.arange(1, 51), linear_doner_world.q_values[1:-1, 0], label = "Up")
plt.plot(np.arange(1, 51), linear_doner_world.q_values[1:-1, 1], label = "Down", linestyle = '--')
plt.xlabel("State")
plt.ylabel("Final Q-value")
plt.title("Final Q-values for Linear Doner World after 50000 Trials")
plt.legend()
plt.show()

preferred_action = np.array([-1 if linear_doner_world.q_values[1:-1, 0][i] < linear_doner_world.q_values[1:-1, 1][i] else 1 for i in range(len(linear_doner_world.q_values[1:-1, 0]))])
preferred_action[linear_doner_world.q_values[1:-1, 0] == linear_doner_world.q_values[1:-1, 1]] = 0
plt.plot(np.arange(1, 51), preferred_action)
plt.ylim(-1.5, 1.5)
plt.yticks([-1, 0, 1])
plt.xlabel("State")
plt.ylabel("Preferred Action")
plt.show()

# %% [markdown]
# #### 1.2 d) Explain your results (0.5 points)
#
# How does the agent behave after learning and why?

# %% [markdown]
# The agent always chooses the bottom-most reward since it always chooses the action downwards to get to it. This is because even if the agent were at the top-most state, walking down to the Good Doner would get a total reward of -10*50 + 1000 > 100

# %% [markdown]
# ### 1.3 Repeat the simulation with different $\gamma$
#
# #### 1.3 Run the simulations (0.5 points)
# Plot the converged Q-values and preferred actions (as in exercise 1.2 c)) for discount factors $\gamma$ = 0.99, 0.95, 0.9, 0.8.

# %%
gammas = np.array([0.99, 0.95, 0.9, 0.8])
n_trials = 50000

fig, ax = plt.subplots(2, 2)
fig2, ax2 = plt.subplots(2, 2)
for i, gamma in enumerate(gammas):
    linear_doner_world = LinearDonerWorld(gamma = gamma)
    mean_q_values , trial_durations = linear_doner_world.train_with_epsilon_greedy(n_trials = n_trials)
    j = 0
    if i >= 2:
        i -= 2
        j = 1
    ax[j, i].plot(np.arange(1, 51), linear_doner_world.q_values[1:-1, 0], label = "Up")
    ax[j, i].plot(np.arange(1, 51), linear_doner_world.q_values[1:-1, 1], label = "Down", linestyle = '--')
    ax[j, i].set_xlabel("State")
    ax[j, i].set_ylabel("Final Q-value")
    ax[j, i].set_title("Final Q-values for \n Linear Doner World \n after 50000 Trials \n using $\gamma $ = {}".format(gamma))
    
    preferred_action = np.array([-1 if linear_doner_world.q_values[1:-1, 0][i] < linear_doner_world.q_values[1:-1, 1][i] else 1 for i in range(len(linear_doner_world.q_values[1:-1, 0]))])
    preferred_action[linear_doner_world.q_values[1:-1, 0] == linear_doner_world.q_values[1:-1, 1]] = 0
    ax2[j, i].plot(np.arange(1, 51), preferred_action)
    ax2[j, i].set_xlabel("State")
    ax2[j, i].set_ylabel("Preferred Action")
    ax2[j, i].set_ylim(-1.5, 1.5)
    ax2[j, i].set_yticks([-1, 0, 1])

ax[1,1].legend()
fig.tight_layout()
fig2.tight_layout()
plt.show()

# %% [markdown]
# #### 1.3 b) Discuss your results (1 point)
#
# How do the Q-values change? How does the final behavior of agent change? Provide an explanation.

# %% [markdown]
# For lower $\gamma$ values (<0.99), the agent does not consider rewards that are very far. The agent goes to the nearest doner in these cases, with the distance the agent is willing to travel to get to the good doner decreasing with decreased $\gamma$.

# %% [markdown]
# ## Exercise 2: Gridworld (13 point)
#
#
# In this exercise you will implement several methods in the class `Gridworld` (defined in `gridworld.py`) for reinforcement learning in 2-dimensions. Most of the class is already complete, but you must now apply your knowledge of 1-dimensional SARSA to a 2-dimensional problem.

# %% [markdown]
# ### 2.0 Animating a trial of an agent
#
# In the following, you will let your agents learn in gridworlds that you define. For visualiztion of the agent's behavior, you can use the `display_animation` function provided in `helpers.py`. This section will show you how an animation should look like once you have solved the exercises below.
#
# Below is an example that should show you a running animation. Here, the `_run_trial` method of the `Gridworld` class was implemented such that the agent walks from the top left corner to the bottom left corner. After executing the cell below, you should see an animation in your Notebook. If this does not work for you, please contact your teaching assistant.

# %%
def _run_from_top_left_to_bottom_left(self):
    """
    Run a single trial on the gridworld where the agent starts at the top left
    corner and walkds to the bottom left corner.
    """

    # Initialize the agent at the top left corner
    self.x_position = 4
    self.y_position = 0
    # visualize the first state in the animation
    self._visualize_current_state()

    # Now do 4 steps downwards
    for _ in range(4):
        # action = 1 means moving downwards (see Gridworld._update_state())
        self.action = 1
        # apply the action aka move the agent
        self._update_state()
        # visualize the new state in the animation
        self._visualize_current_state()

    # The _run_trial function needs to return the latency. Here the agent needs
    # 4 steps to reach the target.
    latency = 4
    return latency


# Overwrite the Gridworld._run_trial method with the function defined here
Gridworld._run_trial = _run_from_top_left_to_bottom_left


# Define a gridworld and display an animated trial
g_test = Gridworld(5)
g_test.run(N_trials=20)
anim = g_test.visualize_trial()
display_animation(anim)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgbd4b340653884e749c5cddc3384a7712">
#   <div class="anim-controls">
#     <input id="_anim_sliderbd4b340653884e749c5cddc3384a7712" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animbd4b340653884e749c5cddc3384a7712.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animbd4b340653884e749c5cddc3384a7712.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animbd4b340653884e749c5cddc3384a7712.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animbd4b340653884e749c5cddc3384a7712.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animbd4b340653884e749c5cddc3384a7712.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animbd4b340653884e749c5cddc3384a7712.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animbd4b340653884e749c5cddc3384a7712.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animbd4b340653884e749c5cddc3384a7712.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animbd4b340653884e749c5cddc3384a7712.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animbd4b340653884e749c5cddc3384a7712.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectbd4b340653884e749c5cddc3384a7712"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_bd4b340653884e749c5cddc3384a7712"
#              >
#       <label for="_anim_radio1_bd4b340653884e749c5cddc3384a7712">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_bd4b340653884e749c5cddc3384a7712"
#              checked>
#       <label for="_anim_radio2_bd4b340653884e749c5cddc3384a7712">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_bd4b340653884e749c5cddc3384a7712"
#              >
#       <label for="_anim_radio3_bd4b340653884e749c5cddc3384a7712">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbd4b340653884e749c5cddc3384a7712";
#     var slider_id = "_anim_sliderbd4b340653884e749c5cddc3384a7712";
#     var loop_select_id = "_anim_loop_selectbd4b340653884e749c5cddc3384a7712";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/NK7nSAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAUJ0lEQ

# %% [markdown]
# ### 2.1 Complete the `Gridworld` class (3 points)
#
# Now that you know how these animations should look like, review the existing code that defines the `Gridworld` class (defined in `gridworld.py`) to get a sense of how the class functions. You can execute
#
# ```python
# Gridworld?
# ```
#
# in a notebook cell to have the class docstring and initializer docstring displayed (which is defined in `gridworld.py`). This gives you an overview of the class attributes and methods available to you.
#
# Provide an implementation for the empty methods `_run_trial`, `_update_Q`, and `_choose_action`. To do that, complete the functions below. At the bottom of the cell, the class methods will be overwritten with your new definitions. Do not modify `gridworld.py` itself!

# %%
Gridworld?

# %%
def _run_trial(self):
    """
    Run a single trial on the gridworld until the agent reaches the reward position.
    Return the time it takes to get there.
    """
    # Initialize the latency (time to reach the target) for this trial
    latency = 0.0

    # Choose a random initial position and make sure that it is not in the wall.
    # Needed here:
    # self.x_position, self.y_position, self._is_wall()
    self.x_position, self.y_position = np.random.randint(0, self.N, size = 2)
    while self._is_wall(self.x_position, self.y_position):
        self.x_position, self.y_position = np.random.randint(0, self.N, size = 2)
    

    # Run the trial by choosing an action and repeatedly applying SARSA
    # until the reward has been reached.
    # Needed here:
    # self._choose_action(), self._arrived(),  self._update_state(), self._update_Q()
    self._choose_action()
    while not self._arrived():
        self._update_state()
        self._choose_action()
        self._update_Q()
        latency += 1

    return latency


def _update_Q(self):
    """
    Update the current estimate of the Q-values according to SARSA.
    """
    # update the eligibility trace
    # YOUR CODE HERE
    self.e *= self.gamma*self.lambda_eligibility
    self.e[self.x_position_old, self.y_position_old, self.action_old] += 1
    

    # update the Q-values:
    #
    #     deltaQ = eta * e * [reward - (Q_old - gamma * Q)]
    #
    # Needed here:
    # self.eta, self.e, self.gamma, self._reward,
    # self.action, self.x_position, self.y_position
    # self.action_old, self.x_position_old, self.y_position_old
    #
    # You need to make sure that your position and action variables are not `None` (which
    # they are initialized as).
    self.Q[self.x_position_old, self.y_position_old, self.action_old] += self.eta*self.e[self.x_position_old, self.y_position_old, self.action_old]*(self._reward() + self.gamma*self.Q[self.x_position, self.y_position, self.action] - self.Q[self.x_position_old, self.y_position_old, self.action_old])
    


def _choose_action(self):
    """
    Choose the next action based on the current estimate of the Q-values.
    The parameter epsilon determines, how often agent chooses the action 
    with the highest Q-value (probability 1-epsilon). In the rest of the cases
    a random action is chosen.
    """
    # Be sure to store the old action before choosing a new one.
    # Needed here:
    # self.action, self.action_old, self.epsilon, self.Q, self.x_position, self.y_position
    self.action_old = self.action
    greedy_action = np.argmax(self.Q[self.x_position, self.y_position])
    self.action = greedy_action if np.random.random() < self.epsilon else np.random.choice(np.arange(0, self.Q.shape[-1]))


# This overwrites the class methods with the functions you defined above
# Note: You are overwriting the methods in the class definition. Therefore, in each class
#       instance you create below - using gridworld.Gridworld(...) - these new functions
#       will be used
Gridworld._run_trial = _run_trial
Gridworld._update_Q = _update_Q
Gridworld._choose_action = _choose_action

# %% [markdown]
# ### 2.2 Test your gridworld
#
# The cell below creates a gridworld of size 5x5 and lets the agent learn for 20 trials. It then visualizes a new trial in an animation. This is only going to show an animation once you have implemented the methods in 2.1.

# %%
# The animation will only show something once you have implemented the methods in 2.1.
g1 = Gridworld(5)
g1.run(N_trials=20)
anim = g1.visualize_trial()
display_animation(anim)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge86b11aebe1e41bd800a029756fc3d36">
#   <div class="anim-controls">
#     <input id="_anim_slidere86b11aebe1e41bd800a029756fc3d36" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime86b11aebe1e41bd800a029756fc3d36.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime86b11aebe1e41bd800a029756fc3d36.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime86b11aebe1e41bd800a029756fc3d36.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime86b11aebe1e41bd800a029756fc3d36.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime86b11aebe1e41bd800a029756fc3d36.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime86b11aebe1e41bd800a029756fc3d36.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime86b11aebe1e41bd800a029756fc3d36.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime86b11aebe1e41bd800a029756fc3d36.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime86b11aebe1e41bd800a029756fc3d36.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime86b11aebe1e41bd800a029756fc3d36.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte86b11aebe1e41bd800a029756fc3d36"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e86b11aebe1e41bd800a029756fc3d36"
#              >
#       <label for="_anim_radio1_e86b11aebe1e41bd800a029756fc3d36">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e86b11aebe1e41bd800a029756fc3d36"
#              checked>
#       <label for="_anim_radio2_e86b11aebe1e41bd800a029756fc3d36">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e86b11aebe1e41bd800a029756fc3d36"
#              >
#       <label for="_anim_radio3_e86b11aebe1e41bd800a029756fc3d36">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge86b11aebe1e41bd800a029756fc3d36";
#     var slider_id = "_anim_slidere86b11aebe1e41bd800a029756fc3d36";
#     var loop_select_id = "_anim_loop_selecte86b11aebe1e41bd800a029756fc3d36";
#     var frames = new Array(4);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/NK7nSAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAUJ0lEQV

# %% [markdown]
# #### 2.2 a) Create a 10x10 gridworld (1 point)
#
# Define a new `Gridworld` of size 10x10 and let the agent learn again for 20 trials.

# %%
g2 = Gridworld(10)
g2.run(N_trials=20)
anim = g2.visualize_trial()
display_animation(anim)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcf815cc719d841ff8daad98872bbd402">
#   <div class="anim-controls">
#     <input id="_anim_slidercf815cc719d841ff8daad98872bbd402" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcf815cc719d841ff8daad98872bbd402.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcf815cc719d841ff8daad98872bbd402.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcf815cc719d841ff8daad98872bbd402.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcf815cc719d841ff8daad98872bbd402.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcf815cc719d841ff8daad98872bbd402.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcf815cc719d841ff8daad98872bbd402.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcf815cc719d841ff8daad98872bbd402.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcf815cc719d841ff8daad98872bbd402.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcf815cc719d841ff8daad98872bbd402.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcf815cc719d841ff8daad98872bbd402.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcf815cc719d841ff8daad98872bbd402"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cf815cc719d841ff8daad98872bbd402"
#              >
#       <label for="_anim_radio1_cf815cc719d841ff8daad98872bbd402">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cf815cc719d841ff8daad98872bbd402"
#              checked>
#       <label for="_anim_radio2_cf815cc719d841ff8daad98872bbd402">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cf815cc719d841ff8daad98872bbd402"
#              >
#       <label for="_anim_radio3_cf815cc719d841ff8daad98872bbd402">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcf815cc719d841ff8daad98872bbd402";
#     var slider_id = "_anim_slidercf815cc719d841ff8daad98872bbd402";
#     var loop_select_id = "_anim_loop_selectcf815cc719d841ff8daad98872bbd402";
#     var frames = new Array(105);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/NK7nSAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAWDElE

# %% [markdown]
# #### 2.2 b) Compare the two gridworlds (1 point)
# What is the qualitative difference in the trials of the two gridworlds and how would you explain it?

# %% [markdown]
# The trials are much longer because the grid world is larger and contains more states to explore, so the agent takes more time to find the reward.

# %% [markdown]
# ### 2.3 Compare the navigation maps and the Q maps
#
# #### 2.3 a) Plot the navigation and Q maps (1 point)
# Look at the navigation map of the agents, i.e., the action with the highest Q-value as a function of position using the class method `navigation_map()`. And also view the Q maps individually with class method `plot_Q()`. Do this for both gridworlds that you simulated above.

# %%
g1.navigation_map()
g2.navigation_map()

g1.plot_Q()
g2.plot_Q()

# %% [markdown]
# #### 2.3 b) Explain the agent's behavior (1 point)
#
# How is the behavior of the agent reflected in the navigation maps? Compare the structure of the maps close to the target position and at larger distances.

# %% [markdown]
# When close to the target position, the agent's preferred actions coincide with the reasonable choice for getting closer to the target. For instance, the Q-values associated with the down and left actions close to the target are high, while not for the up and right actions. At distances further away from the target, the behaviour appears more random, reflected by homogenously low Q-values and incoherent preferred actions. An intuition for this would be that the further away the target, the less obvious the optimal path is.

# %% [markdown]
# ### 2.4 Study the learning curves for both agents
#
# #### 2.4 a) Plot the learning curves (0.5 points)
#
# Quantify this difference by plotting the latencies (i.e., the time it takes the agent to reach the target position) as a function of trial number. This curve is often called the "learning curve". You can use the class method `learning_curve`. To get smoother curves, let the agent take 20 runs on the same problem and plot the latency curve averaged over all runs (rerun the `run` method and pass the number of runs as parameter `N_runs`). Do this for both gridworlds that you defined above.

# %%
g1.run(N_trials = 20, N_runs = 20)
g2.run(N_trials = 20, N_runs = 20)

g1.learning_curve()
g2.learning_curve()

# %% [markdown]
# #### 2.4 b) Compare the learning curves (1.5 points)
#
# 1. Compare the latencies for the 2 gridworlds.
# 2. What are the latencies that you would expect if the agent has discovered the optimal strategy?
# 3. How do they compare to the latencies in the computer simulations?

# %% [markdown]
# 1. The latencies for the larger grid world are almost 10 times larger in scale than the smaller one and remain larger
# 2. If the agent has discovered the optimal strategy, low latencies on the order of the length of the shortest path to the reward are expected. This cannot exceed $N^2$.
# 3. We can see that in both gridworlds the latencies converge or start to converge to below $N^2$, but the larger gridworld seems to converge later. Nevertheless, the optimal strategy should be much lower than $N^2$, which doesn't seem to be reached for the larger gridworld.

# %% [markdown]
# ### 2.5) Study the effect of an eligibility trace
#
# #### 2.5 a) Simulate an agent with eligibility trace (2 points)
#
# Create 2 different gridworlds of size 20x20, one of which learns with an eligibility trace and the other one without. To enable the eligibility trace, set the constructor parameter `lambda_eligibility=0.9`.
# Let the agents learn for 50-200 trials and 20 runs. Plot the Q maps and learning curves for both agents.

# %%
g3 = Gridworld(20)
g3_eligibility = Gridworld(20, lambda_eligibility=0.9)
g3.run(N_trials=200, N_runs = 20)
g3_eligibility.run(N_trials=200, N_runs = 20)

g3.plot_Q()
g3_eligibility.plot_Q()

g3.learning_curve()
g3_eligibility.learning_curve()

# %% [markdown]
# #### 2.5 b) Compare the two agents (2 points)
#
# - Why is the runtime of these simulations rather high?
# - Compare the development of the latencies for the two agents. What do you observe and why?

# %% [markdown]
# In these simulations the size of the world has again been increased (doubled), which, as before, leads to longer trials and a higher runtime.
#
# The learning curve corresponding to where the eligibility trace was applied exhibits less oscillatory dynamics. The trace effectively implements a memory mechanism and weights recently visted states exponentially higher than states visited longer ago. Since all the Q-values for all states are adjusted by the eligibility trace at each time step, this leads to faster information propagation via the Q-values compared to the simple case without the trace. This, in turn, is reflected by the latency decreasing more smoothly, since the Q-values are more expressive at the beginning of each trial.
